# %%
import os
import pandas as pd
import glob
import datetime as dt
import indicators as ind
import visualisation as vis
import utilities as ut
import multiprocessing
from dateutil.relativedelta import relativedelta as rtd

# %%
path = "daily_data"
tocken = 'hbar-usd'
files = glob.glob(f"{path}/{tocken.upper()}/*.csv")

# %%
import selectors


df = pd.read_csv(files[0])
cols = ut.getColNames()
df = df.rename(cols,axis=1)

vis.plotTockenData(df =df,
                   bbbands=True,
                   sma=True,
                   sma_period=14,
                   title=tocken)

# closing_price = df['Close']
# bbupper,bbmiddle, bblower = ind.getBollingerBands(closing_price)

# fig = go.Figure()

# fig.add_trace(go.Candlestick(x=df['Date'],
#                 open=df['Open'],
#                 high=df['High'],
#                 low=df['Low'],
#                 close=df['Close']))

# fig.add_trace(go.Line(x=df['Date'],y = bbupper,
#               name = 'Bollinger Up'))
# fig.add_trace(go.Line(x=df['Date'],y = bblower,
#               name='Bollinger Low'))
# fig.add_trace(go.Line(x=df['Date'],y = bbmiddle,
#               name='Bollinger Middle'))


# fig.update_layout(title = f'{tocken}',
#                   xaxis_title="Date- Slider",
#                   yaxis_title="Price",
#                 )
# fig.show()
#ltc['Close'].plot(figsize=(15,8))
#btc.iloc[:,:-2].plot(figsize=(15,8))
# Out:
# C:\Users\jaysa\AppData\Roaming\Python\Python37\site-packages\plotly\graph_objs\_deprecations.py:385: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.

# %%
sd = dt.datetime.now().date()
delta = -729
ed = sd+ rtd(days = delta)
test = ut.getTickerData('BTC-USD',ed,sd,interval='2h')
test.head(3)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BTC-USD: Invalid input - interval=2h is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
[1m - 7, (2m, 5m, 15m, 30m,90m) - 59, 60m,1h - 729, 1d, 5d, 1wk, 1mo, 3mo]

# %%
from logging import getLevelName

from utilities import getFolderNames


def exportFile(data = res, path = export_path, folder = foldernames.get(level), tocken = ticker, edate = ed):
    
    if data != None:
            
        if not os.path.exists(f"{path}/{folder}/{tocken}"):
            print(f"""
                Status: Creating New Directory || path: {path}/{folder}/{tocken}
                """, end='\r')
            os.mkdir(f"{path}/{folder}/{tocken}")
            data.to_feather(f"{path}/{folder}/{tocken}/{edate}.ftr")
        
        else:
            data.to_csv(f"{path}/{folder}/{tocken}/{edate}.ftr")
        print(f"Ticker: {tocken} || Status: Done...", end = '\r')
    
        del data
    else:
        print(f"{tocken} Dataframe is empty....Continue to next tocken..!!!")
        del data
        continue
# Out:
# 'd'
